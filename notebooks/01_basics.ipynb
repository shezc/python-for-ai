# %% [markdown]
# # Python 基础语法学习
#
# 这个 notebook 演示 Python 的基础语法，适合 Node.js 开发者学习。

# %% [markdown]
# ## 1. 变量和数据类型

# %%
# Python 是动态类型语言，无需声明类型
# Node.js: const name = "Python"
name = "Python"
age = 30
is_learning = True
height = 1.75

print(f"name: {name} (类型: {type(name).__name__})")
print(f"age: {age} (类型: {type(age).__name__})")
print(f"is_learning: {is_learning} (类型: {type(is_learning).__name__})")
print(f"height: {height} (类型: {type(height).__name__})")

# %% [markdown]
# ## 2. 列表（类似 JavaScript 数组）

# %%
# Node.js: const fruits = ["apple", "banana", "orange"]
fruits = ["apple", "banana", "orange"]
print(f"fruits: {fruits}")
print(f"第一个元素: {fruits[0]}")
print(f"列表长度: {len(fruits)}")

# %% [markdown]
# ## 3. 字典（类似 JavaScript 对象）

# %%
# Node.js: const person = { name: "John", age: 30 }
person = {
    "name": "John",
    "age": 30,
    "city": "Beijing"
}
print(f"person: {person}")
print(f"访问属性: person['name'] = {person['name']}")
print(f"访问属性: person.get('age') = {person.get('age')}")

# %% [markdown]
# ## 4. f-string（类似模板字符串）

# %%
# Node.js: `Hello, ${name}!`
name = "Python"
age = 30
message = f"Hello, {name}! You are {age} years old."
print(message)

# %% [markdown]
# ## 5. 列表推导式（类似 map/filter）

# %%
# Node.js: [1,2,3,4,5].map(x => x * x).filter(x => x > 10)
numbers = [1, 2, 3, 4, 5]
squared = [x * x for x in numbers]
squared_filtered = [x * x for x in numbers if x * x > 10]

print(f"原始列表: {numbers}")
print(f"平方: {squared}")
print(f"平方且大于10: {squared_filtered}")

# %% [markdown]
# ## 6. 实验区域
#
# 在这里尝试修改上面的代码，看看会发生什么！

# %%
# 在这里写你的实验代码
# 例如：
my_list = [1, 2, 3]

# %%
# 学习一下list
import copy

list1 = [1,2,3,3,4,5]
list1_4 = list1
list1_5 = copy.deepcopy(list1)
list1_6 = list1.copy()
list1.append(6)
list1.extend([7,8])
list1.insert(7,77)
print(list1.count(3))
print(list1.pop(2))
print(list1.index(7))

list1.sort(key=lambda x:x*2,reverse=True)

list1.reverse()


list2 = list1.copy()
list3 = list1[:]

list4 = [x * 2 for x in list1]
list4_5 = [ x * 2 for x in list1 if x > 5]
list5 = [ x * 2 for x in range(5)]


list6 = [ dict(name=x,age=x+1) for x in list1]
list7 = [x["age"] for x in list6]
list7_5 = [x.get("age") for x in list6]

# list1.clear()
print(f"list1: {list1}")
print(f"list1_4: {list1_4}")
print(f"list1_5: {list1_5}")
print(f"list1_6: {list1_6}")
print(f"list2: {list2}")
print(f"list3: {list3}")
print(f"list4: {list4}")
print(f"list4_5: {list4_5}")
print(f"list5: {list5}")
print(f"list6: {list6}")
print(f"list7: {list7}")
print(f"list7_5: {list7_5}")
# Out:
# 2
# 3
# 7
# list1: [1, 2, 3, 4, 5, 6, 7, 8, 77]
# list1_4: [1, 2, 3, 4, 5, 6, 7, 8, 77]
# list1_5: [1, 2, 3, 3, 4, 5]
# list1_6: [1, 2, 3, 3, 4, 5]
# list2: [1, 2, 3, 4, 5, 6, 7, 8, 77]
# list3: [1, 2, 3, 4, 5, 6, 7, 8, 77]
# list4: [2, 4, 6, 8, 10, 12, 14, 16, 154]
# list4_5: [12, 14, 16, 154]
# list5: [0, 2, 4, 6, 8]
# list6: [{'name': 1, 'age': 2}, {'name': 2, 'age': 3}, {'name': 3, 'age': 4}, {'name': 4, 'age': 5}, {'name': 5, 'age': 6}, {'name': 6, 'age': 7}, {'name': 7, 'age': 8}, {'name': 8, 'age': 9}, {'name': 77, 'age': 78}]
# list7: [2, 3, 4, 5, 6, 7, 8, 9, 78]
# list7_5: [2, 3, 4, 5, 6, 7, 8, 9, 78]
